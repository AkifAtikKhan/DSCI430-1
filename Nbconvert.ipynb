# %%
import pandas as pd
Artists = pd.read_csv('./Artists.csv')

# %%
Artists.head
# Out:
# <bound method NDFrame.head of        ConstituentID                           DisplayName  \
# 0                  1                        Robert Arneson
# 1                  2                        Doroteo Arnaiz
# 2                  3                           Bill Arnold
# 3                  4                       Charles Arnoldi
# 4                  5                           Per Arnoldi
# 5                  6                         Danilo Aroldi
# 6                  7                             Bill Aron
# 7                  9                         David Aronson
# 8                 10                         Irene Aronson
# 9                 11                       Jean (Hans) Arp
# 10                12                            Jüri Arrak
# 11                13                   J. Arrelano Fischer
# 12                15                         Folke Arstrom
# 13                16                     Cristobal Arteche
# ...

# %%
Artists.columns
# Out:
# Index(['ConstituentID', 'DisplayName', 'ArtistBio', 'Nationality', 'Gender',
#        'BeginDate', 'EndDate', 'Wiki QID', 'ULAN'],
#       dtype='object')
